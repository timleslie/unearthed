# %%
import pandas as pd

# %%
# %matplotlib notebook

# %%
MONTH = '2016-01'

# %%
data = pd.read_hdf('/mnt/raw/clean/%s.h5' % MONTH, 'data')

# %%
columns = {
    "FFY28016.P01" : "T1_T2_Ratio",
    "TH006RATIO.CPV" : "T12_T3_Ratio",
    
    "3311HS181A.PV" : "Throughput",
    
    "CalcCY03FRC1.CPV" : "T1_Size",
    "CY02FRC1.CPV" : "T2_Size",
    "3313AI531.PV" : "T3_Size",

    "MIY22937.CPV" : "T1_Output",
    "MIY22953.CPV" : "T2_Output",
    "3312FY078.CPV" : "T3_Output",
}

# %%
data.rename(columns=columns, inplace=True)

# %%
data.loc[pd.Timestamp('2016-01-05') : pd.Timestamp('2016-01-06')].Throughput.plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
data.Throughput.plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
for i in

# %%
data.loc[pd.Timestamp('2016-01-13 09:00') : pd.Timestamp('2016-01-16 11:00')] \
[["T1_Output", "T2_Output", "T3_Output", "Throughput"]]\
.plot()
# Out:
# <img src="data:image/png;base64,...">
