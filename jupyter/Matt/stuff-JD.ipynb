# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib notebook

# %%
MONTH = '2016-03'

# %%
data = pd.read_hdf('/mnt/raw/clean/%s.h5' % MONTH, 'data')

# %%
columns = {
    "FFY28016.P01" : "T1_T2_Ratio",
    "TH006RATIO.CPV" : "T12_T3_Ratio",
    
    "3311WI671.PV" : "Spewput",
    
    "CalcCY03FRC1.CPV" : "T1_Size",
    "CY02FRC1.CPV" : "T2_Size",
    "3313AI531.PV" : "T3_Size",

    "MIY22937.CPV" : "T1_Output",
    "MIY22953.CPV" : "T2_Output",
    "3312FY078.CPV" : "T3_Output",

    "3311WIC151.PV" : "1Speed",
    "SIC22371.MV" : "MillSpeed",
}

# %%
data.rename(columns=columns, inplace=True)

# %%
data.plot.scatter
# Out:
# <bound method FramePlotMethods.scatter of <pandas.tools.plotting.FramePlotMethods object at 0x7f3def8f3a90>>

# %%
sub = data.loc[pd.Timestamp('2016-03-01 01:00') : pd.Timestamp('2016-03-01 02:00')]
plt.subplot(211)
sub.Spewput.plot()
plt.subplot(212)
sub.MillSpeed.plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
sns.pairplot(sub[["Spewput", "MillSpeed"]])
# Out:
# <img src="data:image/png;base64,...">
# /usr/lib/python3/dist-packages/matplotlib/__init__.py:894: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
sub.head()
# Out:
#                         JIC22564     JIC22864  3312JI354.PV  3312FI040.PV  \
# Date
# 2016-03-01 01:00:00  9410.775391  9470.743164   15518.41895    482.232361
# 2016-03-01 01:00:05  9432.177734  9470.743164   15495.38965    481.856903
# 2016-03-01 01:00:10  9488.324219  9415.068359   15578.32617    480.235962
# 2016-03-01 01:00:15  9447.181641  9415.068359   15545.52539    481.961365
# 2016-03-01 01:00:20  9426.116211  9415.068359   15623.99023    481.961365
#
#                      3312FIC040.PV  DI22936-PCT.CPV   FI22937.PV    T1_Output  \
# Date
# 2016-03-01 01:00:00     482.232361        63.604256  3218.670166  2059.514893
# 2016-03-01 01:00:05     481.856903        63.596867  3233.942871  2057.127930
# 2016-03-01 01:00:10     480.235962        63.589474  3186.852783  2060.600342
# 2016-03-01 01:00:15     481.961365        63.582085  3218.668213  2065.956055
# 2016-03-01 01:00:20     481.961365        63.574692  3254.870361  2071.311523
#
#                      PI22925.PV  SI22313.PV    ...      SN2002.PV  \
# Date                                           ...
# 2016-03-01 01:00:00  113.846870   30.559715    ...            NaN
# 2016-03-01 01:00:05  113.843552   30.590311    ...            NaN
# 2016-03-01 01:00:10  113.840225   30.595408    ...            NaN
# 2016-03-01 01:00:15  113.836899   30.590265    ...            NaN
# 2016-03-01 01:00:20  113.833572   30.561680    ...            NaN
#
#                      SY21633B.MV  SY21633C.MV  SY23005.MV  SY23015.MV  \
# Date
# 2016-03-01 01:00:00    46.366558    31.366558   57.574573   73.227966
# 2016-03-01 01:00:05    46.440720    31.440720   57.456829   72.316948
# 2016-03-01 01:00:10    46.523365    31.523367   57.599777   71.795303
# 2016-03-01 01:00:15    46.587254    31.587255   57.634670   71.758247
# 2016-03-01 01:00:20    46.588013    31.588013   56.713791   72.019844
#
#                      WI21633A.PV  SY21633A.MV  WIC22026.SV  WIC22026LAG.RV  \
# Date
# 2016-03-01 01:00:00  2985.716309    46.366558       1022.5     1011.886780
# 2016-03-01 01:00:05  3000.057861    46.440720       1022.5     1011.974609
# 2016-03-01 01:00:10  2995.512940    46.523365       1022.5     1012.341492
# 2016-03-01 01:00:15  3009.443604    46.587254       1022.5     1012.798035
# 2016-03-01 01:00:20  3008.849121    46.588013       1022.5     1013.254639
#
#                       YIC22001
# Date
# 2016-03-01 01:00:00  46.269859
# 2016-03-01 01:00:05  46.256443
# 2016-03-01 01:00:10  46.161041
# 2016-03-01 01:00:15  46.037846
# 2016-03-01 01:00:20  45.917732
#
# [5 rows x 119 columns]

# %%
sub.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-91575f6cbaf7> in <module>()
# ----> 1 sub.columns()
#
# TypeError: 'Index' object is not callable

# %%
print(sub.columns)
# Out:
# Index(['JIC22564', 'JIC22864', '3312JI354.PV', '3312FI040.PV', '3312FIC040.PV',
#        'DI22936-PCT.CPV', 'FI22937.PV', 'T1_Output', 'PI22925.PV',
#        'SI22313.PV',
#        ...
#        'SN2002.PV', 'SY21633B.MV', 'SY21633C.MV', 'SY23005.MV', 'SY23015.MV',
#        'WI21633A.PV', 'SY21633A.MV', 'WIC22026.SV', 'WIC22026LAG.RV',
#        'YIC22001'],
#       dtype='object', length=119)

# %%
sns.distplot(data['T1_Output'])
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.show()
