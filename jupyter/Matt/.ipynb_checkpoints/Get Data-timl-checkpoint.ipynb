# %%
import pandas as pd

# %%
# %matplotlib notebook

# %%
MONTH = '2016-01'

# %%
data = pd.read_hdf('/mnt/raw/clean/%s.h5' % MONTH, 'data')

# %%
columns = {
    "FFY28016.P01" : "T1_T2_Ratio",
    "TH006RATIO.CPV" : "T12_T3_Ratio",
    
    "3311HS181A.PV" : "Throughput",
    
    "CalcCY03FRC1.CPV" : "T1_Size",
    "CY02FRC1.CPV" : "T2_Size",
    "3313AI531.PV" : "T3_Size",

    "MIY22937.CPV" : "T1_Output",
    "MIY22953.CPV" : "T2_Output",
    "3312FY078.CPV" : "T3_Output",
    
    "SI82603": "P1_Speed",
    "SI82605": "P2_Speed",
    
    "SI22313.PV": "P1_Hz",
    "SI22315.PV": "P2_Hz",
    
    "PI22925.PV": "P1_Pressure",
    "PI22941.PV": "P2_Pressure",
    
    "MIY22937.CPV": "P1_Mass",
    "MIY22953.CPV": "P2_Mass",
    }
dead_columns = ["T1_T2_Ratio", "T12_T3_Ratio", "SN2001.PV", "SN2002.PV", "3311FV380B.PV",
                "CR002RUN", "CR003RUN", "3311FV690B.PV", "3312DI075.PV", "3312DI075A.PV"]

# %%
data.rename(columns=columns, inplace=True)
for c in dead_columns:
    del data[c]

# %%
day_data = data.loc[pd.Timestamp('2016-01-05') : pd.Timestamp('2016-01-06')]

# %%
day_data.Throughput.plot()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
day_data[["T1_Output", "T2_Output", "T3_Output", "Throughput"]].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-213-8ddf58ce5642> in <module>()
# ----> 1 day_data[["T1_Output", "T2_Output", "T3_Output", "Throughput"]].plot()
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    1961         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1962             # either boolean or fancy integer index
# -> 1963             return self._getitem_array(key)
#    1964         elif isinstance(key, DataFrame):
#    1965             return self._getitem_frame(key)
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2005             return self.take(indexer, axis=0, convert=False)
#    2006         else:
# -> 2007             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2008             return self.take(indexer, axis=1, convert=True)
#    2009
#
# /usr/lib/python3/dist-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1148                 mask = check == -1
#    1149                 if mask.any():
# -> 1150                     raise KeyError('%s not in index' % objarr[mask])
#    1151
#    1152                 return _values_from_object(indexer)
#
# KeyError: "['T1_Output' 'T2_Output'] not in index"

# %%
day_data[["T1_Size", "T2_Size", "T3_Size"]].plot()

# %%
day_data[["P1_Hz", "P2_Hz"]].plot()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
day_data[["P1_Pressure", "P2_Pressure"]].plot()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
day_data[["P2_Hz"]].plot()
# Out:
# ---------------------------------------------------------------------------
# NonGuiException                           Traceback (most recent call last)
# <ipython-input-147-44a03e6a27f1> in <module>()
# ----> 1 day_data[["P2_Hz"]].plot()
#
# /usr/lib/python3/dist-packages/pandas/tools/plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3669                           fontsize=fontsize, colormap=colormap, table=table,
#    3670                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3671                           sort_columns=sort_columns, **kwds)
#    3672     __call__.__doc__ = plot_frame.__doc__
#    3673
#
# /usr/lib/python3/dist-packages/pandas/tools/plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2554                  yerr=yerr, xerr=xerr,
#    2555                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2556                  **kwds)
#    2557
#    2558
#
# /usr/lib/python3/dist-packages/pandas/tools/plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2382         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2383
# -> 2384     plot_obj.generate()
#    2385     plot_obj.draw()
#    2386     return plot_obj.result
#
# /usr/lib/python3/dist-packages/pandas/tools/plotting.py in generate(self)
#     985         self._compute_plot_data()
#     986         self._setup_subplots()
# --> 987         self._make_plot()
#     988         self._add_table()
#     989         self._make_legend()
#
# /usr/lib/python3/dist-packages/pandas/tools/plotting.py in _make_plot(self)
#    1662                              stacking_id=stacking_id,
#    1663                              is_errorbar=is_errorbar,
# -> 1664                              **kwds)
#    1665             self._add_legend_handle(newlines[0], label, index=i)
#    1666
#
# /usr/lib/python3/dist-packages/pandas/tools/plotting.py in _ts_plot(cls, ax, x, data, style, **kwds)
#    1701         lines = cls._plot(ax, data.index, data.values, style=style, **kwds)
#    1702         # set date formatter, locators and rescale limits
# -> 1703         format_dateaxis(ax, ax.freq)
#    1704         return lines
#    1705
#
# /usr/lib/python3/dist-packages/pandas/tseries/plotting.py in format_dateaxis(subplot, freq)
#     291         "y = {1:8f}".format(Period(ordinal=int(t), freq=freq), y))
#     292
# --> 293     pylab.draw_if_interactive()
#
# /usr/local/lib/python3.5/dist-packages/IPython/utils/decorators.py in wrapper(*args, **kw)
#      41     def wrapper(*args,**kw):
#      42         wrapper.called = False
# ---> 43         out = func(*args,**kw)
#      44         wrapper.called = True
#      45         return out
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_nbagg.py in draw_if_interactive()
#      65         manager = pylab_helpers.Gcf.get_active()
#      66         if manager is not None:
# ---> 67             manager.show()
#      68
#      69
#
# /usr/lib/python3/dist-packages/matplotlib/backend_bases.py in show(self)
#    2618         optional warning.
#    2619         """
# -> 2620         raise NonGuiException()
#    2621
#    2622     def destroy(self):
#
# NonGuiException:

# %%
day_data[["P1_Speed"]].plot()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
matrix = day_data.corr()
import matplotlib.pyplot as p
p.imshow(matrix)
# p.show()

# %%
# %matplotlib inline
import scipy.signal as ss
N = len(day_data)
c = ss.correlate(day_data["P1_Speed"], day_data["P1_Hz"], mode="full")
print(N  - 1 - c.argmax())
p.plot(c)
# p.show()
# Out:
# 0
