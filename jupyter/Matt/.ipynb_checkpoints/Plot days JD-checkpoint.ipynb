# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/lib/python3/dist-packages/matplotlib/__init__.py:874: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
# %matplotlib notebook

# %%
MONTH = '2016-02'

# %%
data = pd.read_hdf('/mnt/raw/clean/%s.h5' % MONTH, 'data')

# %%
columns = {
    "FFY28016.P01" : "T1_T2_Ratio",
    "TH006RATIO.CPV" : "T12_T3_Ratio",
    
    "3311WI671.PV" : "Spewput",
    
    "CalcCY03FRC1.CPV" : "T1_Size",
    "CY02FRC1.CPV" : "T2_Size",
    "3313AI531.PV" : "T3_Size",

    "MIY22937.CPV" : "T1_Output",
    "MIY22953.CPV" : "T2_Output",
    "3312FY078.CPV" : "T3_Output",

    "3311WIC151.PV" : "1Speed",
    "SIC22371.MV" : "MillSpeed",
}

# %%
data.rename(columns=columns, inplace=True)

# %%
col = ["MillSpeed","1Speed","T3_Output","T2_Output","T1_Output","T3_Size","T2_Size","T1_Size","Spewput","T12_T3_Ratio","T1_T2_Ratio"]

# %%
col
# Out:
# ['MillSpeed',
#  '1Speed',
#  'T3_Output',
#  'T2_Output',
#  'T1_Output',
#  'T3_Size',
#  'T2_Size',
#  'T1_Size',
#  'Spewput',
#  'T12_T3_Ratio',
#  'T1_T2_Ratio']

# %%
data.head()
# Out:
#                         JIC22564     JIC22864  3312JI354.PV  3312FI040.PV  \
# Date
# 2016-02-01 00:00:00  9367.324219  9437.850586   15465.80078    299.357941
# 2016-02-01 00:00:05  9434.013672  9437.850586   15418.30859    299.357941
# 2016-02-01 00:00:10  9426.369141  9437.850586   15491.72656    297.917755
# 2016-02-01 00:00:15  9412.333984  9446.027344   15433.48340    298.919830
# 2016-02-01 00:00:20  9418.494141  9446.027344   15438.94141    299.961121
#
#                      3312FIC040.PV  DI22936-PCT.CPV   FI22937.PV    T1_Output  \
# Date
# 2016-02-01 00:00:00     299.357941        82.471283  3061.199707  2534.670410
# 2016-02-01 00:00:05     299.357941        82.471283  3077.497803  2534.514160
# 2016-02-01 00:00:10     297.917755        82.471283  3070.100098  2534.357910
# 2016-02-01 00:00:15     298.919830        82.471283  3052.965820  2532.616211
# 2016-02-01 00:00:20     299.961121        82.471283  3046.303223  2529.302490
#
# ...

# %%
days = [12,21,24]

# %%
day12 = data.loc[pd.Timestamp('2016-02-12 00:00') : pd.Timestamp('2016-02-13 00:00')]

# %%
day12.head()
# Out:
#                         JIC22564     JIC22864  3312JI354.PV  3312FI040.PV  \
# Date
# 2016-02-12 00:00:00  9750.970703  9505.194336   15419.95117    456.837921
# 2016-02-12 00:00:05  9715.890625  9505.194336   15373.70215    456.866119
# 2016-02-12 00:00:10  9692.518555  9505.194336   15513.75977    457.237793
# 2016-02-12 00:00:15  9691.123047  9582.626953   15390.86719    455.248901
# 2016-02-12 00:00:20  9728.207031  9582.626953   15409.61133    455.215271
#
#                      3312FIC040.PV  DI22936-PCT.CPV   FI22937.PV    T1_Output  \
# Date
# 2016-02-12 00:00:00     456.837921        61.058533  3117.294434  1917.766480
# 2016-02-12 00:00:05     456.866119        61.056438  3130.453613  1922.151611
# 2016-02-12 00:00:10     457.237793        61.054340  3156.892578  1926.536621
# 2016-02-12 00:00:15     455.248901        61.052246  3159.172852  1930.522217
# 2016-02-12 00:00:20     455.215271        61.050148  3121.623535  1932.156982
#
# ...

# %%
day21 = data.loc[pd.Timestamp('2016-02-21 00:00') : pd.Timestamp('2016-02-23 00:00')]

# %%
day24 = data.loc[pd.Timestamp('2016-02-24 00:00') : pd.Timestamp('2016-02-25 00:00')]

# %%
for i in col:
    sns.distplot(day12[i])
    plt.savefig('plots/20160212_hist_%s.png' %i)
    plt.figure()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# /usr/lib/python3/dist-packages/numpy/lib/function_base.py:564: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n = np.zeros(bins, ntype)
# /usr/lib/python3/dist-packages/numpy/lib/function_base.py:600: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   n += np.bincount(indices, weights=tmp_w, minlength=bins).astype(ntype)
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# ---------------------------------------------------------------------------
# ...

# %%
sns.pairplot(day12[col[:6]].iloc[:10000])
# Out:
# <img src="data:image/png;base64,...">
# /usr/lib/python3/dist-packages/matplotlib/__init__.py:894: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
colmatrix = day12[col].corr()

# %%
sns.heatmap(colmatrix, vmax=.8, square=True)

# %%
plt.show()

# %%
sns.heatmap(colmatrix)
# Out:
# <img src="data:image/png;base64,...">
