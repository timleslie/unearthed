# %%
import pandas as pd

# %%
pd.read_csv(r"/mnt/raw/scores_for_matt.csv").set_index('Date')
# Out:
#                      Score
# Date
# 2016-07-28 00:10:05  0.358
# 2016-07-28 00:11:05  0.384
# 2016-07-28 00:12:05  0.402
# 2016-07-28 00:13:05  0.410
# 2016-07-28 00:14:05  0.388
# 2016-07-28 00:15:05  0.426
# 2016-07-28 00:16:05  0.420
# 2016-07-28 00:17:05  0.370
# 2016-07-28 00:18:05  0.368
# 2016-07-28 00:19:05  0.370
# 2016-07-28 00:20:05  0.376
# 2016-07-28 00:21:05  0.416
# 2016-07-28 00:22:05  0.458
# 2016-07-28 00:23:05  0.574
# 2016-07-28 00:24:05  0.580
# 2016-07-28 00:25:05  0.528
# 2016-07-28 00:26:05  0.484
# 2016-07-28 00:27:05  0.470
# 2016-07-28 00:28:05  0.424
# 2016-07-28 00:29:05  0.360
# 2016-07-28 00:30:05  0.330
# 2016-07-28 00:31:05  0.254
# 2016-07-28 00:32:05  0.310
# 2016-07-28 00:33:05  0.332
# 2016-07-28 00:34:05  0.360
# 2016-07-28 00:35:05  0.394
# 2016-07-28 00:36:05  0.410
# 2016-07-28 00:37:05  0.402
# 2016-07-28 00:38:05  0.400
# 2016-07-28 00:39:05  0.348
# ...                    ...
# 2016-07-28 23:30:05  0.356
# 2016-07-28 23:31:05  0.310
# ...
