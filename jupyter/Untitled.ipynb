# %%
import pandas
data = pandas.read_csv("/mnt/raw/Surge-2016-01.csv")
print(data)
# Out:
#                        Date  1101047CL1.CPV2  3212WQIPC1-2  3311FV380B.PV  \
# 0       01/01/2016 00:00:00           255488   1693.929443            NaN
# 1       01/01/2016 00:00:05           255488   1803.577637            NaN
# 2       01/01/2016 00:00:10           255488   1892.909302            NaN
# 3       01/01/2016 00:00:15           255488   1966.084595            NaN
# 4       01/01/2016 00:00:20           255492   2023.494019            NaN
# 5       01/01/2016 00:00:25           255494   2078.693604            NaN
# 6       01/01/2016 00:00:30           255496   2126.172607            NaN
# 7       01/01/2016 00:00:35           255501   2169.717529            NaN
# 8       01/01/2016 00:00:40           255505   2204.320068            NaN
# 9       01/01/2016 00:00:45           255509   2233.575928            NaN
# 10      01/01/2016 00:00:50           255513   2258.476318            NaN
# 11      01/01/2016 00:00:55           255520   2278.673584            NaN
# ...

# %%
# %matplotlib inline
data["3311HS181A.PV"].plot()
